# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as mlt 
import seaborn as sns 
import plotly.express as px 
from mlxtend.plotting import plot_decision_regions

# %%
df = pd.read_csv("C:\GEN1_AI\Dataset\Deep Learning\churn.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\G'
# <>:1: SyntaxWarning: invalid escape sequence '\G'
# C:\Users\Anooj Dilip Archana\AppData\Local\Temp\ipykernel_15704\2612172330.py:1: SyntaxWarning: invalid escape sequence '\G'
#   df = pd.read_csv("C:\GEN1_AI\Dataset\Deep Learning\churn.csv")

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df = df.drop(columns = ['CustomerId', 'RowNumber', 'Surname', 'Geography', 'Gender'], axis=1)

# %%
df.head(3)
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2       0.00              1          1
# 1          608   41       1   83807.86              1          0
# 2          502   42       8  159660.80              3          1
#
#    IsActiveMember  EstimatedSalary  Exited
# 0               1        101348.88       1
# 1               1        112542.58       0
# 2               0        113931.57       1

# %%
df.isnull().sum()
# Out:
# CreditScore        0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
input_data = df.iloc[:,:-1]
output_data = df.iloc[:,-1]

# %%
input_data
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary
# 0                  1        101348.88
# 1                  1        112542.58
# ...

# %%
output_data
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: Exited, Length: 10000, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss = StandardScaler()
sf = ss.fit_transform(input_data)

# %%
input_data = pd.DataFrame(sf, columns=input_data.columns)
input_data
# Out:
#       CreditScore       Age    Tenure   Balance  NumOfProducts  HasCrCard  \
# 0       -0.326221  0.293517 -1.041760 -1.225848      -0.911583   0.646092
# 1       -0.440036  0.198164 -1.387538  0.117350      -0.911583  -1.547768
# 2       -1.536794  0.293517  1.032908  1.333053       2.527057   0.646092
# 3        0.501521  0.007457 -1.387538 -1.225848       0.807737  -1.547768
# 4        2.063884  0.388871 -1.041760  0.785728      -0.911583   0.646092
# ...           ...       ...       ...       ...            ...        ...
# 9995     1.246488  0.007457 -0.004426 -1.225848       0.807737   0.646092
# 9996    -1.391939 -0.373958  1.724464 -0.306379      -0.911583   0.646092
# 9997     0.604988 -0.278604  0.687130 -1.225848      -0.911583  -1.547768
# 9998     1.256835  0.293517 -0.695982 -0.022608       0.807737   0.646092
# 9999     1.463771 -1.041433 -0.350204  0.859965      -0.911583   0.646092
#
#       IsActiveMember  EstimatedSalary
# 0           0.970243         0.021886
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 import tensorflow
#
# ModuleNotFoundError: No module named 'tensorflow'
