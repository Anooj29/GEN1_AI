# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as mlt
import plotly as pt
import plotly.express as px
import seaborn as sb

# %%
df = pd.read_csv("C:\GEN1_AI\Dataset\Machine_Learning\crops\Crop_recommendation.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\G'
# <>:1: SyntaxWarning: invalid escape sequence '\G'
# C:\Users\Anooj Dilip Archana\AppData\Local\Temp\ipykernel_23540\2793917666.py:1: SyntaxWarning: invalid escape sequence '\G'
#   df = pd.read_csv("C:\GEN1_AI\Dataset\Machine_Learning\crops\Crop_recommendation.csv")

# %%
df
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536    rice
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537    rice
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248    rice
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034    rice
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340    rice
# ...   ...  ..  ..          ...        ...       ...         ...     ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee
#
# [2200 rows x 8 columns]

# %%
df.shape
# Out:
# (2200, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   N            2200 non-null   int64
#  1   P            2200 non-null   int64
#  2   K            2200 non-null   int64
#  3   temperature  2200 non-null   float64
#  4   humidity     2200 non-null   float64
#  5   ph           2200 non-null   float64
#  6   rainfall     2200 non-null   float64
#  7   label        2200 non-null   object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 137.6+ KB

# %%
df.describe()
# Out:
#                  N            P            K  temperature     humidity  \
# count  2200.000000  2200.000000  2200.000000  2200.000000  2200.000000
# mean     50.551818    53.362727    48.149091    25.616244    71.481779
# std      36.917334    32.985883    50.647931     5.063749    22.263812
# min       0.000000     5.000000     5.000000     8.825675    14.258040
# 25%      21.000000    28.000000    20.000000    22.769375    60.261953
# 50%      37.000000    51.000000    32.000000    25.598693    80.473146
# 75%      84.250000    68.000000    49.000000    28.561654    89.948771
# max     140.000000   145.000000   205.000000    43.675493    99.981876
#
#                 ph     rainfall
# count  2200.000000  2200.000000
# mean      6.469480   103.463655
# std       0.773938    54.958389
# min       3.504752    20.211267
# 25%       5.971693    64.551686
# 50%       6.425045    94.867624
# 75%       6.923643   124.267508
# max       9.935091   298.560117

# %%
list(df.columns)
# Out:
# ['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall', 'label']

# %%
df.isnull().sum()
# Out:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64

# %%
fig = px.histogram(df,
                   x='temperature', 
                   marginal='box',
                   nbins=47,
                   title='Temperature')
fig.update_layout(width=800, height=600, bargap=0.1)
fig.show()

# %%
fig = px.histogram(df,
                   x='humidity', 
                   marginal='box',
                   color_discrete_sequence=['red'],
                   nbins=47,
                   title='Humidity')
fig.update_layout(width=800, height=600, bargap=0.1)
fig.show()

# %%
fig = px.scatter(df, 
                 x='temperature',
                 y='humidity',
                 color='temperature',
                 opacity=0.8,
                 hover_data=['label'],
                 title='Temp. v/s Humidity')
fig.update_traces(marker_size=5)
fig.update_layout(width=800, height=600, bargap=0.02)
fig.show()

# %%
df = df.drop('N', axis=1)

# %%
df = df.drop('P', axis=1)

# %%
df = df.drop('K', axis=1)

# %%
df
# Out:
#       temperature   humidity        ph    rainfall   label
# 0       20.879744  82.002744  6.502985  202.935536    rice
# 1       21.770462  80.319644  7.038096  226.655537    rice
# 2       23.004459  82.320763  7.840207  263.964248    rice
# 3       26.491096  80.158363  6.980401  242.864034    rice
# 4       20.130175  81.604873  7.628473  262.717340    rice
# ...           ...        ...       ...         ...     ...
# 2195    26.774637  66.413269  6.780064  177.774507  coffee
# 2196    27.417112  56.636362  6.086922  127.924610  coffee
# 2197    24.131797  67.225123  6.362608  173.322839  coffee
# 2198    26.272418  52.127394  6.758793  127.175293  coffee
# 2199    23.603016  60.396475  6.779833  140.937041  coffee
#
# [2200 rows x 5 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df
# Out:
#       temperature   humidity        ph    rainfall   label
# 0       20.879744  82.002744  6.502985  202.935536    rice
# 1       21.770462  80.319644  7.038096  226.655537    rice
# 2       23.004459  82.320763  7.840207  263.964248    rice
# 3       26.491096  80.158363  6.980401  242.864034    rice
# 4       20.130175  81.604873  7.628473  262.717340    rice
# ...           ...        ...       ...         ...     ...
# 2195    26.774637  66.413269  6.780064  177.774507  coffee
# 2196    27.417112  56.636362  6.086922  127.924610  coffee
# 2197    24.131797  67.225123  6.362608  173.322839  coffee
# 2198    26.272418  52.127394  6.758793  127.175293  coffee
# 2199    23.603016  60.396475  6.779833  140.937041  coffee
#
# [2200 rows x 5 columns]

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
df
# Out:
#       temperature   humidity        ph    rainfall   label
# 0       20.879744  82.002744  6.502985  202.935536    rice
# 1       21.770462  80.319644  7.038096  226.655537    rice
# 2       23.004459  82.320763  7.840207  263.964248    rice
# 3       26.491096  80.158363  6.980401  242.864034    rice
# 4       20.130175  81.604873  7.628473  262.717340    rice
# ...           ...        ...       ...         ...     ...
# 2195    26.774637  66.413269  6.780064  177.774507  coffee
# 2196    27.417112  56.636362  6.086922  127.924610  coffee
# 2197    24.131797  67.225123  6.362608  173.322839  coffee
# 2198    26.272418  52.127394  6.758793  127.175293  coffee
# 2199    23.603016  60.396475  6.779833  140.937041  coffee
#
# [2200 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
X = df[['temperature', 'humidity']]
Y = df['label']

# %%
X
# Out:
#       temperature   humidity
# 0       20.879744  82.002744
# 1       21.770462  80.319644
# 2       23.004459  82.320763
# 3       26.491096  80.158363
# 4       20.130175  81.604873
# ...           ...        ...
# 2195    26.774637  66.413269
# 2196    27.417112  56.636362
# 2197    24.131797  67.225123
# 2198    26.272418  52.127394
# 2199    23.603016  60.396475
#
# [2200 rows x 2 columns]

# %%
Y
# Out:
# 0         rice
# 1         rice
# 2         rice
# 3         rice
# 4         rice
#          ...
# 2195    coffee
# 2196    coffee
# 2197    coffee
# 2198    coffee
# 2199    coffee
# Name: label, Length: 2200, dtype: object

# %%
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 2
#       1 label_encoder = LabelEncoder()
# ----> 2 y_encoded = label_encoder.fit_transform(y)
#
# NameError: name 'y' is not defined

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# %%
X_train
# Out:
#       temperature   humidity
# 1656    16.396243  92.181519
# 752     27.543848  69.347863
# 892     27.521856  63.132153
# 1041    25.360592  75.031933
# 1179    35.474783  47.972305
# ...           ...        ...
# 1638    21.213070  91.353492
# 1095    27.359116  84.546250
# 1130    27.920633  51.779659
# 1294    13.429886  80.066340
# 860     23.970814  62.355576
#
# [1760 rows x 2 columns]

# %%
sc.fit(X_train)
# Out:
# StandardScaler()

# %%
x_train = sc.transform(X_train)
x_test = sc.transform(X_test)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test).round()

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.02727272727272727

# %%
model = LogisticRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# c:\Users\Anooj Dilip Archana\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# 0.25227272727272726
